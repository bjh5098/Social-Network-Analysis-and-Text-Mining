# %% [markdown]
# <a href="https://colab.research.google.com/github/bjh5098/Social-Network-Analysis-and-Text-Mining/blob/master/SNA_1_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Intro NetworkX

# %% [markdown]
# ## 네트워크 분석의 시작

# %%
import networkx as nx

# %%
g = nx.Graph()

# %%
g.add_edge('a', 'b', weight=0.1)
g.add_edge('b', 'c', weight=1.5)
g.add_edge('a', 'c', weight=1.0)
g.add_edge('c', 'd', weight=10)

# %%
nx.draw(g, with_labels=True, weighted=True)

# %% [markdown]
# ### 노드(node) 추가 및 삭제하기

# %%
g.add_node('e')

# %%
g.add_nodes_from(['e', 'f'])

# %%
nx.draw(g, with_labels=True, weighted=True)

# %%
g.node
# Out:
# NodeView(('a', 'b', 'c', 'd', 'e', 'f'))

# %%
g.remove_node('f')

# %%
g.nodes()
# Out:
# NodeView(('a', 'b', 'c', 'd', 'e'))

# %% [markdown]
# ### 엣지(edge) 추가하기

# %%
g.edges()
# Out:
# EdgeView([('a', 'b'), ('a', 'c'), ('b', 'c'), ('c', 'd')])

# %%
g.add_edge('e', 'd', weight=4)

# %%
g.edges()
# Out:
# EdgeView([('a', 'b'), ('a', 'c'), ('b', 'c'), ('c', 'd'), ('d', 'e')])

# %%
g.add_edges_from([('e','f'), ('e', 'a')])

# %%
g.edges()
# Out:
# EdgeView([('a', 'b'), ('a', 'c'), ('a', 'e'), ('b', 'c'), ('c', 'd'), ('d', 'e'), ('e', 'f')])

# %%
g.remove_edge('e','f')

# %%
g.edges()
# Out:
# EdgeView([('a', 'b'), ('a', 'c'), ('a', 'e'), ('b', 'c'), ('c', 'd'), ('d', 'e')])

# %% [markdown]
# ### 노드와 엣지 접근

# %%
g.number_of_nodes()
# Out:
# 6

# %%
g.number_of_edges()
# Out:
# 6

# %%
g.size()
# Out:
# 6

# %%
g.degree
# Out:
# DegreeView({'a': 3, 'b': 2, 'c': 3, 'd': 2, 'e': 2, 'f': 0})

# %%
list(g.neighbors('a'))
# Out:
# ['b', 'c', 'e']

# %%
g.add_node('a', major='CS', gender = "M", st_id = '2019111111')

# %%
g.node['a']
# Out:
# {'gender': 'M', 'major': 'CS', 'st_id': '2019111111'}

# %%
g['e']['d']['weight']
# Out:
# 4

# %%
g['a']['b']['weight']
# Out:
# 0.1

# %% [markdown]
# ## 네트워크 시각화

# %%
nx.draw(g)

# %%
nx.draw(g, with_labels=True)

# %%
nx.draw(g, with_labels=True, font_size=20, font_color='white', edge_color='red', node_color='black')

# %%
nx.draw(g, with_labels=True, font_color='white', edge_color='red', node_color='black',node_size=800, node_shape='*')

# %%
nx.draw(g, with_labels=True, font_color='white', edge_color='red', node_color='black',node_size=800, node_shape='*', linewidths=10)

# %%
nx.draw(g, with_labels=True, font_color='white', edge_color='red', node_color='black',node_size=800, node_shape='*', width = 3)

# %%
nx.draw(g, with_labels=True, font_color='white', edge_color='red', node_color='black',node_size=800, node_shape='*', width = 3, style = 'dashed')

# %%
nx.draw_random(g, with_labels=True)

# %%
nx.draw_circular(g, with_labels=True)

# %%
nx.draw_spectral(g, with_labels=True)

# %% [markdown]
# https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.drawing.nx_pylab.draw_networkx.html?highlight=draw_networkx
